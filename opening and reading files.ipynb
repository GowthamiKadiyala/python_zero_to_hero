# %%
from collections import Counter

# %%
mylist = [1,2,2,2,3,3,3,5]

# %%
Counter(mylist)
# Out:
# Counter({2: 3, 3: 3, 1: 1, 5: 1})

# %%
pwd
# Out:
# '/Users/gowthamikadiyala/Documents/python_zero_to_hero'

# %%
f = open("practice.txt", "w+")
f.write('This is a test str')
f.close()

# %%
import os

# %%
os.getcwd()
# Out:
# '/Users/gowthamikadiyala/Documents/python_zero_to_hero'

# %%
os.listdir('/Users')
# Out:
# ['.localized', 'Shared', 'gowthamikadiyala']

# %%
import shutil

# %%
shutil.move('practice.txt','/Users/gowthamikadiyala')
# Out:
# '/Users/gowthamikadiyala/practice.txt'

# %%
os.listdir('/Users/gowthamikadiyala')
# Out:
# ['.config',
#  'Music',
#  '.yarn',
#  '.condarc',
#  '.DS_Store',
#  'project_llm',
#  '.CFUserTextEncoding',
#  '.angular-config.json',
#  '.xonshrc',
#  'GOWTHAMIKADIYALA_resume.pdf',
#  'Untitled.ipynb',
#  '.zshrc',
#  'Projects',
#  'Pictures',
#  '.zprofile',
#  'practice.txt',
#  'IdeaSnapshots',
#  'Postman',
#  '.zsh_history',
#  '.ipython',
#  'Desktop',
#  'Library',
#  '.matplotlib',
#  '.lesshst',
#  'Public',
#  '.tcshrc',
#  '.virtual_documents',
#  '.anaconda',
#  'Movies',
#  'Applications',
#  'GOWTHAMI_resume.docx',
#  '.Trash',
#  'IdeaProjects',
#  '.ipynb_checkpoints',
#  '.jupyter',
#  '.npm',
#  '.terraform.d',
#  'Documents',
#  '.BrowserLock',
#  '.vscode',
#  '.m2',
#  '.bash_profile',
#  'Downloads',
#  '.python_history',
#  '.continuum',
#  '.aws',
#  '.ollama',
#  '.zsh_sessions',
#  '.conda']
